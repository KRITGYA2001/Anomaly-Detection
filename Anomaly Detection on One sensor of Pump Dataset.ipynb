# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # Data Cleaning

# %%
df=pd.read_csv('onesensor.csv')

# %%
df=df.set_index('index')

# %%
df.head()
# Out:
#    index    sensor
# 0      1  47.09201
# 1      2  47.09201
# 2      3  47.35243
# 3      4  47.09201
# 4      5  47.13541

# %%
df.tail()
# Out:
#      index    sensor
# 995    996  47.52604
# 996    997  47.17882
# 997    998  46.87500
# 998    999  46.65799
# 999   1000  47.09201

# %%
df.sample(5)
# Out:
#      index    sensor
# 180    181  49.13194
# 755    756  47.13541
# 280    281  47.13541
# 494    495  46.18055
# 175    176  48.56771

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   1000 non-null   int64
#  1   sensor  1000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 15.8 KB

# %%
df.describe()
# Out:
#              index       sensor
# count  1000.000000  1000.000000
# mean    500.500000    47.667663
# std     288.819436     1.029159
# min       1.000000    45.789930
# 25%     250.750000    46.744790
# 50%     500.500000    47.526040
# 75%     750.250000    48.697910
# max    1000.000000    49.565970

# %%
df.shape
# Out:
# (1000, 2)

# %%
df.columns
# Out:
# Index(['index', 'sensor'], dtype='object')

# %%
df.isnull().sum()
# Out:
# index     0
# sensor    0
# dtype: int64

# %%
df['sensor'].fillna((df['sensor'].mean()),inplace=True)

# %%
df.isnull().sum()
# Out:
# index     0
# sensor    0
# dtype: int64

# %%
sb.set()
sb.relplot(x='index',y='sensor',data=df)

# %%
sb.set()
sb.relplot(x='index',y='sensor',kind='line',data=df)

# %%
sb.set()
sb.distplot(df['sensor'])
# Out:
# C:\Users\kritg\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sensor', ylabel='Density'>

# %%
newdf=df[(df['sensor'] > 49.5) | (df['sensor'] < 46)]
print(newdf)
# Out:
#      index    sensor
# 151    152  49.52257
# 152    153  49.56597
# 154    155  49.52257
# 158    159  49.52257
# 159    160  49.52257
# 160    161  49.52257
# 161    162  49.56597
# 368    369  45.78993
# 592    593  45.96354
# 603    604  45.96354
# 848    849  45.78993

# %%
plt.plot(df['sensor'], color='black')
plt.title("sensor")
plt.show()

# %%
_ = plt.figure(figsize=(9,7))
_ = plt.scatter(df['index'],df['sensor'])
_ = plt.xlabel('PC0')
_ = plt.ylabel('PC1')
_ = plt.title('K-means of clustering')
plt.show()

# %%
sb.boxplot(df['sensor'])
# Out:
# C:\Users\kritg\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sensor'>
